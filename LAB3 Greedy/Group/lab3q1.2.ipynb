# %%
# greedy ที่ซ้ายไปขวา ใกล้สุด <==>
def greedy(arr,k):
    count = 0
    for i in range(len(arr)):
        if arr[i] =='G' :
            paired = False
            # print("founded 'G' at "+str(i))
            for a in range(i-1,i-1-k,-1): # ซ้าย <=
                if(a >= 0):
                    if arr[a] == 'P':
                        #print("paired w/ P back at index:"+str(a))
                        #pair and delete and count
                        count+=1
                        arr[a]='X'
                        paired = True
                        break
            if(not paired):   
                for b in range(i+1,i+1+k): #ขวา =>    
                    if(b < len(arr)):
                        # print(":)")      
                        if arr[b] == 'P':  
                            #print("paired w/ P front at index:"+str(b))
                            #pair and delete and count
                            count+=1
                            arr[b]='X'
                            paired = True
                            break
    print(arr)
    return count

arr1 = ['G', 'P', 'P', 'G', 'P']
arr2 = ['P', 'P', 'G', 'G', 'P', 'G']
arr3 =['G', 'P', 'G', 'P', 'P', 'G']
extra_arr1=['G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P']
extra_arr2=['G','G','P','P','G','G','G','G','P','P','P','G']
extra_arr3=['G','G','P','P','G','P','P','P','G','G','P','P']
extra_arr5=['P','P','G','P','G','P']
                
print(greedy(arr1, 1)) 
print(greedy(arr2, 2))
print(greedy(arr3, 3))
print(greedy(extra_arr1, 2))
print(greedy(extra_arr2, 3))
print(greedy(extra_arr3, 3))
print("******************")
print(greedy(extra_arr5, 2))
# Out:
# ['G', 'X', 'X', 'G', 'P']
# 2
# ['P', 'X', 'G', 'G', 'X', 'G']
# 2
# ['G', 'X', 'G', 'X', 'X', 'G']
# 3
# ['G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X']
# 10
# ['G', 'G', 'X', 'X', 'G', 'G', 'G', 'G', 'X', 'X', 'X', 'G']
# 5
# ['G', 'G', 'X', 'X', 'G', 'X', 'X', 'X', 'G', 'G', 'P', 'P']
# 5
# ['P', 'P', 'P', 'X', 'G', 'G', 'G', 'X', 'X', 'P']
# 3
# ['P', 'X', 'G', 'X', 'G', 'P']
# 2

# %%
# greedy ที่ซ้ายไปขวา ไกลสุด =><=
def greedy(arr,k):
    count = 0
    for i in range(len(arr)):
        if arr[i] =='G' :
            paired = False
            # print("founded 'G' at "+str(i))
            for a in range(i-k,i): # ซ้าย =>
                if(a >= 0):
                    if arr[a] == 'P':
                        #print("paired w/ P back at index:"+str(a))
                        #pair and delete and count
                        count+=1
                        arr[a]='X'
                        paired = True
                        break
            if(not paired):   
                for b in range(i+1,i+1+k):  #ขวา <=    
                    if(b < len(arr)):
                        # print(":)")      
                        if arr[b] == 'P':  
                            #print("paired w/ P front at index:"+str(b))
                            #pair and delete and count
                            count+=1
                            arr[b]='X'
                            paired = True
                            break
    print(arr)
    return count

arr1 = ['G', 'P', 'P', 'G', 'P']
arr2 = ['P', 'P', 'G', 'G', 'P', 'G']
arr3 =['G', 'P', 'G', 'P', 'P', 'G']
extra_arr1=['G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P']
extra_arr2=['G','G','P','P','G','G','G','G','P','P','P','G']
extra_arr3=['G','G','P','P','G','P','P','P','G','G','P','P']
extra_arr5=['P','P','G','P','G','P']


print(greedy(arr1, 1)) 
print(greedy(arr2, 2))
print(greedy(arr3, 3))
print(greedy(extra_arr1, 2))
print(greedy(extra_arr2, 3))
print(greedy(extra_arr3, 3))
print("******************")
print(greedy(extra_arr5, 2))
# Out:
# ['G', 'X', 'X', 'G', 'X']
# 1
# ['X', 'X', 'G', 'G', 'X', 'G']
# 1
# ['G', 'X', 'G', 'X', 'X', 'G']
# 0
# ['G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X']
# 0
# ['G', 'G', 'X', 'X', 'G', 'G', 'G', 'G', 'X', 'X', 'X', 'G']
# 0
# ['G', 'G', 'X', 'X', 'G', 'X', 'X', 'X', 'G', 'G', 'X', 'X']
# 2
# ['P', 'P', 'X', 'X', 'G', 'G', 'G', 'X', 'X', 'P']
# 1
# ['X', 'X', 'G', 'X', 'G', 'X']
# 2

# %%
# greedy ที่ขวาไปซ้าย ไกลสุด <=<=
def greedy(arr,k):
    count = 0
    for i in range(len(arr)):
        if arr[i] =='G' :
            paired = False
            # print("founded 'G' at "+str(i))
            for b in range(i+1,i+1+k):  #ขวา <=    
                    if(b < len(arr)):
                        # print(":)")      
                        if arr[b] == 'P':  
                            #print("paired w/ P front at index:"+str(b))
                            #pair and delete and count
                            count+=1
                            arr[b]='X'
                            paired = True
                            break
            if(not paired):   
                for a in range(i-1,i-1-k,-1): # ซ้าย <=
                    if(a >= 0):
                        if arr[a] == 'P':
                            #print("paired w/ P back at index:"+str(a))
                            #pair and delete and count
                            count+=1
                            arr[a]='X'
                            paired = True
                            break
              
    print(arr)
    return count


arr1 = ['G', 'P', 'P', 'G', 'P']
arr2 = ['P', 'P', 'G', 'G', 'P', 'G']
arr3 =['G', 'P', 'G', 'P', 'P', 'G']
extra_arr1=['G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P','G','P']
extra_arr2=['G','G','P','P','G','G','G','G','P','P','P','G']
extra_arr3=['G','G','P','P','G','P','P','P','G','G','P','P']
extra_arr5=['P','P','G','G','P','P']          

print(greedy(arr1, 1)) 
print(greedy(arr2, 2))
print(greedy(arr3, 3))
print(greedy(extra_arr1, 2))
print(greedy(extra_arr2, 3))
print(greedy(extra_arr3, 3))
print("******************")
print(greedy(extra_arr5, 2))
# Out:
# ['G', 'X', 'P', 'G', 'X']
# 2
# ['P', 'X', 'G', 'G', 'X', 'G']
# 2
# ['G', 'X', 'G', 'X', 'X', 'G']
# 3
# ['G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X', 'G', 'X']
# 10
# ['G', 'G', 'X', 'X', 'G', 'G', 'G', 'G', 'X', 'X', 'X', 'G']
# 5
# ['G', 'G', 'X', 'X', 'G', 'X', 'P', 'P', 'G', 'G', 'X', 'X']
# 5
# ******************
# ['P', 'P', 'G', 'G', 'X', 'X']
# 2
