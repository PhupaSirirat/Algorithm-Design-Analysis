# %%
import time

# %%
def is_prime(n):
    operations = 0
    if n < 2:
        operations += 1
        return False, operations
    for i in range(2, int(n**0.5) + 1):
        operations += 1
        if n % i == 0:
            operations += 1
            return False, operations
    operations += 1
    return True, operations

def prime_factorization(n):
    factors = []
    operations = 0
    for i in range(2, n + 1):
        is_prime_result, prime_ops = is_prime(i)
        operations += prime_ops
        operations += 1
        if is_prime_result:
            while n % i == 0:
                operations += 1
                factors.append(i)
                n //= i
            if n == 1:
                break
    return factors, operations

def FindGCD1(m, n):
    total_operations = 0
    
    print("Step 1: Prime factorization of m")
    m_factors, m_ops = prime_factorization(m)
    print(f"Factors of {m}: {m_factors}")
    print(f"Operations for Step 1: {m_ops}")
    total_operations += m_ops
    
    print("\nStep 2: Prime factorization of n")
    n_factors, n_ops = prime_factorization(n)
    print(f"Factors of {n}: {n_factors}")
    print(f"Operations for Step 2: {n_ops}")
    total_operations += n_ops
    
    print("\nStep 3: Find common prime factors")
    common_factors = []
    m_index = n_index = 0
    step3_ops = 0
    while m_index < len(m_factors) and n_index < len(n_factors):
        step3_ops += 1
        if m_factors[m_index] == n_factors[n_index]:
            common_factors.append(m_factors[m_index])
            m_index += 1
            n_index += 1
        elif m_factors[m_index] < n_factors[n_index]:
            m_index += 1
        else:
            n_index += 1
    print(f"Common factors: {common_factors}")
    print(f"Operations for Step 3: {step3_ops}")
    total_operations += step3_ops
    
    print("\nStep 4: Compute GCD")
    gcd = 1
    step4_ops = 0
    for factor in common_factors:
        gcd *= factor
        step4_ops += 1
    print(f"GCD({m}, {n}) = {gcd}")
    print(f"Operations for Step 4: {step4_ops}")
    total_operations += step4_ops
    
    print(f"\nTotal operations: {total_operations}")

# %%
def GCD(m, n):
    print("-" * 50)
    start_time = time.time()
    FindGCD1(m, n)
    end_time = time.time()
    execution_time = end_time - start_time
    print(f"Execution time: {execution_time:.6f} seconds")
    print("-" * 50)

# %%
# Example usage
GCD(48, 18)
# Out:
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 48: [2, 2, 2, 2, 3]
# Operations for Step 1: 9
#
# Step 2: Prime factorization of n
# Factors of 18: [2, 3, 3]
# Operations for Step 2: 7
#
# Step 3: Find common prime factors
# Common factors: [2, 3]
# Operations for Step 3: 5
#
# Step 4: Compute GCD
# GCD(48, 18) = 6
# Operations for Step 4: 2
#
# Total operations: 23
# Execution time: 0.000042 seconds
# --------------------------------------------------

# %%
# Regular case
GCD(111, 234)
GCD(60, 225)
GCD(42, 584010)
GCD(11, 13)
GCD(7854, 4746)
GCD(89406024,277984)
GCD(742271756, 606228865)
# Out:
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 111: [3, 37]
# Operations for Step 1: 137
#
# Step 2: Prime factorization of n
# Factors of 234: [2, 3, 3, 13]
# Operations for Step 2: 41
#
# Step 3: Find common prime factors
# Common factors: [3]
# Operations for Step 3: 4
#
# Step 4: Compute GCD
# GCD(111, 234) = 3
# Operations for Step 4: 1
#
# Total operations: 183
# Execution time: 0.000124 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 60: [2, 2, 3, 5]
# Operations for Step 1: 14
#
# Step 2: Prime factorization of n
# Factors of 225: [3, 3, 5, 5]
# Operations for Step 2: 14
#
# Step 3: Find common prime factors
# Common factors: [3, 5]
# Operations for Step 3: 5
#
# Step 4: Compute GCD
# GCD(60, 225) = 15
# Operations for Step 4: 2
#
# Total operations: 35
# Execution time: 0.000039 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 42: [2, 3, 7]
# Operations for Step 1: 19
#
# Step 2: Prime factorization of n
# Factors of 584010: [2, 3, 3, 3, 3, 5, 7, 103]
# Operations for Step 2: 467
#
# Step 3: Find common prime factors
# Common factors: [2, 3, 7]
# Operations for Step 3: 7
#
# Step 4: Compute GCD
# GCD(42, 584010) = 42
# Operations for Step 4: 3
#
# Total operations: 496
# Execution time: 0.000084 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 11: [11]
# Operations for Step 1: 31
#
# Step 2: Prime factorization of n
# Factors of 13: [13]
# Operations for Step 2: 38
#
# Step 3: Find common prime factors
# Common factors: []
# Operations for Step 3: 1
#
# Step 4: Compute GCD
# GCD(11, 13) = 1
# Operations for Step 4: 0
#
# Total operations: 70
# Execution time: 0.000030 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 7854: [2, 3, 7, 11, 17]
# Operations for Step 1: 57
#
# Step 2: Prime factorization of n
# Factors of 4746: [2, 3, 7, 113]
# Operations for Step 2: 519
#
# Step 3: Find common prime factors
# Common factors: [2, 3, 7]
# Operations for Step 3: 5
#
# Step 4: Compute GCD
# GCD(7854, 4746) = 42
# Operations for Step 4: 3
#
# Total operations: 584
# Execution time: 0.000182 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 89406024: [2, 2, 2, 3, 3725251]
# Operations for Step 1: 438958987
#
# Step 2: Prime factorization of n
# Factors of 277984: [2, 2, 2, 2, 2, 7, 17, 73]
# Operations for Step 2: 313
#
# Step 3: Find common prime factors
# Common factors: [2, 2, 2]
# Operations for Step 3: 9
#
# Step 4: Compute GCD
# GCD(89406024, 277984) = 8
# Operations for Step 4: 3
#
# Total operations: 438959312
# Execution time: 15.983409 seconds
# --------------------------------------------------
# --------------------------------------------------
# Step 1: Prime factorization of m
# Factors of 742271756: [2, 2, 1229, 150991]
# Operations for Step 1: 5155280
#
# Step 2: Prime factorization of n
# Factors of 606228865: [5, 11, 73, 150991]
# Operations for Step 2: 5155280
#
# Step 3: Find common prime factors
# Common factors: [150991]
# Operations for Step 3: 7
#
# Step 4: Compute GCD
# GCD(742271756, 606228865) = 150991
# Operations for Step 4: 1
#
# Total operations: 10310568
# Execution time: 0.322646 seconds
# --------------------------------------------------
